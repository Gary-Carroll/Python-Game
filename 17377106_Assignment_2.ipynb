# %% [markdown]
# # Exercise 1

# %% [markdown]
# #### Creature class

# %%
import random as rand
import sys

class Creature():
    def __init__(self,name,abilities,maxHP=10):
        self.maxHP = maxHP
        self.name = name
        self.hp = maxHP
        self.abilities = {'Attack':abilities[0],'Defense':abilities[1],'Speed':abilities[2]}
    def check_life(self):
        if self.hp < 0:
            print(self.name,'died.')
            return 0
        else:
            return self.hp
    def roll(self,x,y):
        num = rand.randint(x,y)
        return num
    def attack(self,target):
        print(self.name,'attacks',str(target.name)+'.')
        a = self.roll(1,20)
        if a < target.abilities['Defense']+target.abilities['Speed']:
            print('Attack missed.')
        else:
            damage = (self.abilities['Attack'] + self.roll(1,4))
            target.hp -= damage
            print('Attack hits for',damage,'damage!')
    def turn(self,round_num,target):
        self.attack(target)
        if target.hp <= 0:
            print(target.name,'died.')
            return True
        else:
            return False

# %% [markdown]
# Script to create creatures Gollum and Bilbo and show them fighting over a maximum of 20 rounds.

# %%
gollum = Creature('Gollum',(1,2,4),4)
bilbo = Creature('Bilbo', (1,4,3))
roundnumber = 1
while roundnumber < 21:
    print('Round '+str(roundnumber)+':')
    gollum.turn(roundnumber,bilbo)
    if bilbo.hp <= 0:
        break
    bilbo.turn(roundnumber,gollum)
    if gollum.hp <= 0:
        break
    roundnumber+=1
# Out:
# Round 1:
# Gollum attacks Bilbo.
# Attack missed.
# Bilbo attacks Gollum.
# Attack missed.
# Round 2:
# Gollum attacks Bilbo.
# Attack hits for 2 damage!
# Bilbo attacks Gollum.
# Attack hits for 5 damage!
# Gollum died.

# %% [markdown]
# #### Fighter class

# %%
class Fighter(Creature):
    def __init__(self,name):
        Creature.__init__(self,name,abilities=(5,10,3),maxHP=50)
        self.flag = 0
        
    def shield_up(self):
        if self.flag == 0:
            self.abilities['Attack'] -= 5
            self.abilities['Defense'] += 5
            self.flag = 1
            print(self.name,'takes a defensive stance.')
            
    def shield_down(self):
        if self.flag == 1:
            self.abilities['Attack'] += 5
            self.abilities['Defense'] -= 5
            self.flag = 0
            print(str(self.name)+'\'s stance returns to normal.')
        
    def turn(self,round_num,target):
        if round_num % 4 == 1:
            Creature.turn(self,round_num,target)
            if target.hp > 0:
                self.shield_up()
        elif round_num % 4 == 0:
            self.shield_down()
            Creature.turn(self,round_num,target)
        else:
            Creature.turn(self,round_num,target)

# %% [markdown]
# Script creating fighter Aragorn and creature Gollum and showing them fighting over a maximum of 20 rounds.

# %%
fighter = Fighter('Aragorn')
gollum = Creature('Goblin',(1,2,4))
roundnumber = 1
while roundnumber < 21:
    print('Round '+str(roundnumber)+':')
    fighter.turn(roundnumber,gollum)
    if gollum.hp <= 0:
        break
    gollum.turn(roundnumber,fighter)
    if fighter.hp <= 0:
        break
    roundnumber+=1
# Out:
# Round 1:
# Aragorn attacks Goblin.
# Attack hits for 9 damage!
# Aragorn takes a defensive stance.
# Goblin attacks Aragorn.
# Attack missed.
# Round 2:
# Aragorn attacks Goblin.
# Attack missed.
# Goblin attacks Aragorn.
# Attack missed.
# Round 3:
# Aragorn attacks Goblin.
# Attack hits for 1 damage!
# Goblin died.

# %% [markdown]
# #### Archer class

# %%
class Archer(Creature):
    def __init__(self,name,flag=0):
        Creature.__init__(self,name,abilities=(7,8,8),maxHP=30)
        self.flag=flag
        
    def sneak_attack(self,target):
        roll1 = rand.randint(1,20)
        roll2 = rand.randint(1,20)
        maxroll = max(roll1,roll2)
        if self.abilities['Speed'] > target.abilities['Speed']:
            maxroll += (self.abilities['Speed'] - target.abilities['Speed'])
        if self.flag == 0:
            self.abilities['Attack'] += 3
            print(self.name+'\'s attack increased.')
            self.abilities['Defense'] -= 3
            print(self.name+'\'s defense decreased.')
            self.flag = 1
        print(self.name,'sneak attacks',str(target.name)+'.')
        damage = self.roll(1,8) + self.abilities['Attack']
        target.hp -= damage
        print('Sneak attack hits for',damage,'damage.')
        
    def attack(self, target):
        if self.flag == 1:
            self.abilities['Attack'] -= 3
            print(self.name+'\'s attack decreased.')
            self.abilities['Defense'] += 3
            print(self.name+'\'s defense increased.')
            self.flag = 0
        Creature.attack(self,target)
        
    def turn(self,round_num, target):
        if round_num % 4 == 1:
            Creature.turn(self,round_num,target)
        else:
            self.sneak_attack(target)
            if target.hp <= 0:
                print(target.name,'died.')

# %% [markdown]
# Script creating fighter Aragorn and archer Legolas and showing them fighting over a maximum of 20 rounds.

# %%
fighter = Fighter('Aragorn')
archer = Archer('Legolas')
roundnumber = 1
while roundnumber < 21:
    print('Round '+str(roundnumber)+':')
    archer.turn(roundnumber,fighter)
    if fighter.hp <= 0:
        break
    fighter.turn(roundnumber,archer)
    if archer.hp <= 0:
        break
    roundnumber+=1
if roundnumber == 21:
    print('Fight over, nobody was killed.')
# Out:
# Round 1:
# Legolas attacks Aragorn.
# Attack hits for 9 damage!
# Aragorn attacks Legolas.
# Attack missed.
# Aragorn takes a defensive stance.
# Round 2:
# Legolas's attack increased.
# Legolas's defense decreased.
# Legolas sneak attacks Aragorn.
# Sneak attack hits for 12 damage.
# Aragorn attacks Legolas.
# Attack missed.
# Round 3:
# Legolas sneak attacks Aragorn.
# Sneak attack hits for 12 damage.
# Aragorn attacks Legolas.
# Attack missed.
# Round 4:
# Legolas sneak attacks Aragorn.
# Sneak attack hits for 12 damage.
# Aragorn's stance returns to normal.
# Aragorn attacks Legolas.
# Attack missed.
# Round 5:
# Legolas's attack decreased.
# Legolas's defense increased.
# Legolas attacks Aragorn.
# Attack hits for 10 damage!
# Aragorn died.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# #### Goblin and Orc classes

# %%
class Goblin(Creature):
    def __init__(self,name):
        Creature.__init__(self,name,abilities=(4,6,6),maxHP=15)
        self.flag = 0
        
class Orc(Creature):
    def __init__(self,name):
        Creature.__init__(self,name,abilities=(10,6,2),maxHP=50)
        self.flag = 0
        
    def heavy_attack(self,target):
        if self.flag == 0:
            self.abilities['Attack'] += 5
            self.abilities['Defense'] -= 3
            print(self.name,'is in rage.')
            self.flag = 1
        Creature.attack(self,target)
    
    def attack(self,target):
        if self.flag == 1:
            self.abilities['Attack'] -= 5
            self.abilities['Defense'] += 3
            print(self.name,'cooled down.')
            self.flag = 0
        Creature.attack(self,target)
            
    def turn(self,round_num,target):
        if round_num % 4 != 0:
            Creature.turn(self,round_num,target)
        else:
            self.heavy_attack(target)
            if target.hp <= 0:
                print(target.name,'died.')

# %% [markdown]
# Script creating Goblin and Orc and showing them fighting over a maximum of 20 rounds.

# %%
goblin = Goblin('Goblin')
orc = Orc('Orc')
roundnumber = 1
while roundnumber < 21:
    print('Round '+str(roundnumber)+':')
    goblin.turn(roundnumber,orc)
    if orc.hp <= 0:
        break
    orc.turn(roundnumber,goblin)
    if goblin.hp <= 0:
        break
    roundnumber+=1
if roundnumber == 21:
    print('Fight over, nobody was killed.')
# Out:
# Round 1:
# Goblin attacks Orc.
# Attack hits for 5 damage!
# Orc attacks Goblin.
# Attack missed.
# Round 2:
# Goblin attacks Orc.
# Attack missed.
# Orc attacks Goblin.
# Attack missed.
# Round 3:
# Goblin attacks Orc.
# Attack hits for 6 damage!
# Orc attacks Goblin.
# Attack missed.
# Round 4:
# Goblin attacks Orc.
# Attack missed.
# Orc is in rage.
# Orc attacks Goblin.
# Attack missed.
# Round 5:
# Goblin attacks Orc.
# Attack hits for 5 damage!
# Orc cooled down.
# Orc attacks Goblin.
# Attack missed.
# Round 6:
# Goblin attacks Orc.
# Attack missed.
# Orc attacks Goblin.
# Attack hits for 14 damage!
# Round 7:
# Goblin attacks Orc.
# Attack hits for 5 damage!
# Orc attacks Goblin.
# Attack missed.
# Round 8:
# Goblin attacks Orc.
# Attack missed.
# Orc is in rage.
# Orc attacks Goblin.
# Attack missed.
# Round 9:
# Goblin attacks Orc.
# Attack hits for 6 damage!
# Orc cooled down.
# Orc attacks Goblin.
# Attack hits for 11 damage!
# Goblin died.

# %% [markdown]
# #### OrcGeneral and GoblinKing classes

# %%
class OrcGeneral(Orc,Fighter):
    def __init__(self,name):
        Creature.__init__(self,name,abilities=(10,6,2),maxHP=100)
        self.flag = 0

    def turn(self,round_num,target):
        if round_num % 4 == 1:
            Creature.turn(self,round_num,target)
            if target.hp > 0:
                self.shield_up()
        elif round_num % 4 == 2:
            Creature.attack(self,target)
            if target.hp <= 0:
                print(target.name,'died.')
        elif round_num % 4 == 3:
            self.shield_down()
            Creature.turn(self,round_num,target)
        else:
            self.heavy_attack(target)
            if target.hp <= 0:
                print(target.name,'died.')

class GoblinKing(Goblin,Archer):
    def __init__(self,name):
        Creature.__init__(self,name,abilities=(4,6,6),maxHP=50)
        self.flag = 0
        
    def turn(self,round_num,target):
        Archer.turn(self,round_num,target)

# %% [markdown]
# Script creating OrcGeneral Azog and GoblinKing Great Goblin and showing them fighting over a maximum of 20 rounds.

# %%
azog = OrcGeneral('Azog')
goblinking = GoblinKing('Great Goblin')
roundnumber = 1
while roundnumber < 21:
    print('Round '+str(roundnumber)+':')
    azog.turn(roundnumber,goblinking)
    if goblinking.hp <= 0:
        break
    goblinking.turn(roundnumber,azog)
    if azog.hp <= 0:
        break
    roundnumber+=1
if roundnumber == 21:
    print('Fight over, nobody was killed.')
# Out:
# Round 1:
# Azog attacks Great Goblin.
# Attack missed.
# Azog takes a defensive stance.
# Great Goblin attacks Azog.
# Attack missed.
# Round 2:
# Azog attacks Great Goblin.
# Attack missed.
# Great Goblin's attack increased.
# Great Goblin's defense decreased.
# Great Goblin sneak attacks Azog.
# Sneak attack hits for 8 damage.
# Round 3:
# Azog's stance returns to normal.
# Azog attacks Great Goblin.
# Attack hits for 14 damage!
# Great Goblin sneak attacks Azog.
# Sneak attack hits for 10 damage.
# Round 4:
# Azog is in rage.
# Azog attacks Great Goblin.
# Attack hits for 16 damage!
# Great Goblin sneak attacks Azog.
# Sneak attack hits for 8 damage.
# Round 5:
# Azog cooled down.
# Azog attacks Great Goblin.
# Attack missed.
# Azog takes a defensive stance.
# Great Goblin's attack decreased.
# Great Goblin's defense increased.
# Great Goblin attacks Azog.
# Attack hits for 7 damage!
# Round 6:
# Azog attacks Great Goblin.
# Attack hits for 6 damage!
# Great Goblin's attack increased.
# Great Goblin's defense decreased.
# Great Goblin sneak attacks Azog.
# Sneak attack hits for 12 damage.
# Round 7:
# Azog's stance returns to normal.
# Azog attacks Great Goblin.
# Attack missed.
# Great Goblin sneak attacks Azog.
# Sneak attack hits for 10 damage.
# Round 8:
# Azog is in rage.
# Azog attacks Great Goblin.
# Attack hits for 17 damage!
# Great Goblin died.

# %% [markdown]
# # Exercise 3

# %% [markdown]
# #### Wizard class

# %%
class Wizard(Creature):
    def __init__(self,name,maxHP=20,mana=100):
        Creature.__init__(self,name,abilities=(3,5,5),maxHP=20)
        self.abilities = self.abilities|{'Arcana':10}
        self.mana = mana
        self.maxHP = maxHP
        self.hp = maxHP
        
    def attack(self,target):
        if self.mana > 80:
            self.mana = 100
        else:
            self.mana += 20
        Creature.attack(self,target)
        
    def recharge(self):
        initial = self.mana
        if self.mana == 100:
            print('Mana is already full.')
        elif self.mana > 70:
            print('Gandalf channels magical energy...')
            self.mana = 100
            change = self.mana-initial
            print('Mana: +'+str(change))
        else:
            print('Gandalf channels magical energy...')
            self.mana += 30
            print('Mana: +30')
            
    def firebolt(self,target):
        a = self.roll(1,20)
        print(self.name,'fires a fire bolt at',str(target.name)+'.')
        if a < target.abilities['Defense']+target.abilities['Speed']:
            print('Fire bolt missed.')

        else:
            damage = (self.abilities['Attack'] + self.roll(1,4) + (self.abilities['Arcana']//2))
            target.hp -= damage
            print('Fire bolt hits for',damage,'fire damage!')
            if self.mana == 100:
                print('Mana is full.')
            elif self.mana > 90:
                self.mana = 100
            else:
                self.mana += 10
        
    def heal(self,target):
        if self.mana >= 20:
            initialhp = target.hp
            a = self.roll(0,8) + (self.abilities['Arcana']//2)
            target.hp += a
            if target.hp > target.maxHP:
                target.hp = target.maxHP
            self.mana -= 20
            heal = target.hp - initialhp
            if heal == 0:
                print(target.name,'already has full HP.')
            else:
                print(self.name,'heals',target.name,'for',heal,'HP.')
        else:
            print(self.name,'does not have enough mana to heal',str(target.name)+'.')
            
    def mass_heal(self,allies):
        if self.mana >= 30:
            print('Mana: -30')
            for ally in allies:
                initialhp = ally.hp
                a = self.roll(0,10) + (self.abilities['Arcana']//2)
                ally.hp  += a
                if ally.hp > ally.maxHP:
                    ally.hp = ally.maxHP
                heal = ally.hp - initialhp
                if heal == 0:
                    print(ally.name,'already has full HP.')
                else:
                    print(self.name,'heals',ally.name,'for',heal,'HP.')
            self.mana -= 30
        else:
            print(self.name,'does not have enough mana to heal allies.')
            
    def fire_storm(self,enemies):
        if self.mana >= 50:
            print('Mana: -50')
            self.mana = self.mana - 50
            for enemy in enemies:
                a = self.roll(1,20) + self.abilities['Speed']
                damage = self.roll(5,20) + self.abilities['Arcana']
                if a >= self.abilities['Arcana']:
                    enemy.hp -= damage//2
                    print('Fire Storm deals',damage//2,'damage to',str(enemy.name)+'!')
                    if enemy.hp <= 0:
                        print(enemy.name,'died.')
                else:
                    enemy.hp -= damage
                    print('Fire Storm deals',damage,'damage to',str(enemy.name)+'!')
        else:
            print(self.name,'does not have enough mana to use Fire Storm')

# %% [markdown]
# Script showing all Wizard methods.

# %%
wizard = Wizard('Gandalf')
fighter = Fighter('Aragorn')
archer = Archer('Legolas')
allies = (wizard,fighter,archer)
orcgeneral = OrcGeneral('Azog')
orc = Orc('Bolg')
enemies = (orcgeneral,orc)

print('-------------')
print('Using attack:')
print('-------------')
wizard.attack(orc)
print('---------------')
print('Using recharge:')
print('---------------')
wizard.recharge()
print('----------------')
print('Using fire bolt:')
print('----------------')
wizard.firebolt(orcgeneral)
print('-----------')
print('Using heal:')
print('-----------')
wizard.heal(fighter)
print('----------------')
print('Using mass heal:')
print('----------------')
wizard.mass_heal(allies)
print('-----------------')
print('Using fire storm:')
print('-----------------')
wizard.fire_storm(enemies)
# Out:
# -------------
# Using attack:
# -------------
# Gandalf attacks Bolg.
# Attack hits for 7 damage!
# ---------------
# Using recharge:
# ---------------
# Mana is already full.
# ----------------
# Using fire bolt:
# ----------------
# Gandalf fires a fire bolt at Azog.
# Fire bolt hits for 9 fire damage!
# Mana is full.
# -----------
# Using heal:
# -----------
# Aragorn already has full HP.
# ----------------
# Using mass heal:
# ----------------
# Mana: -30
# Gandalf already has full HP.
# Aragorn already has full HP.
# Legolas already has full HP.
# -----------------
# Using fire storm:
# -----------------
# Mana: -50
# Fire Storm deals 7 damage to Azog!
# Fire Storm deals 14 damage to Bolg!

# %% [markdown]
# # Exercise 4

# %% [markdown]
# #### Battle class

# %%
class Battle():
    def __init__(self):
        global heroes, enemies, allies, goblinking, orcgeneral, orc, goblin, wizard, fighter, fighter2, fighter3, archer
        heroes, enemies, allies = [], [], []
        orcgeneral, orc, orc2 = OrcGeneral('Azog'), Orc('Bolg'), Orc('Shagrat')
        goblinking, goblin = GoblinKing('Great Goblin'), Goblin('Snaga')
        wizard, archer = Wizard('Gandalf',40), Archer('Legolas') # Gave Gandalf 40 HP because he kept dying with 20
        fighter, fighter2 = Fighter('Aragorn'),Fighter('Boromir')
        enemies.extend([goblinking,orcgeneral,orc,orc2,goblin])
        allies.extend([fighter,fighter2,archer])
        heroes.extend([fighter,fighter2,archer,wizard])
        
    def auto_select(self,target_list):
        alive = list(filter(lambda x: x.hp > 0, target_list))
        rand.shuffle(alive)
        if len(alive) > 0:
            return alive[0]
        else:
            return None
            
    def select_target(self,target_list):
        alive = list(filter(lambda x: x.hp > 0, target_list))
        numlist = []
        num = 1
        print('Select target:')
        for i in alive:
            print(str(num)+':',str(i.name)+', HP: '+str(i.hp)+'/'+str(i.maxHP))
            numlist.append(num)
            num+=1
        x = 0
        while x not in numlist:
            x = int(input('Enter choice: '))
            if x not in numlist:
                print(x,'is not a valid choice. Enter choice: ')
        print(alive[x-1].name,'chosen.')
        return alive[x-1]
    
    def start(self):
        print('THE BATTLE BEGINS')
        roundnum = 1
        players = []
        for i in enemies:
            players.append(i)
        for j in heroes:
            players.append(j)
        living_enemies = list(filter(lambda x: x.hp > 0, enemies))
        living_allies = list(filter(lambda x: x.hp > 0, allies))
        living_heroes = list(filter(lambda x: x.hp > 0, heroes))
        while len(living_enemies) > 0 and wizard.hp > 0 and len(living_allies) > 0:
            print('========================================================')
            print('Round',str(roundnum)+'.')
            print('========================================================')
            alive = list(filter(lambda x: x.hp > 0, players))
            sequence = sorted(alive, key=lambda x: x.abilities['Speed'], reverse=True)
            for i in sequence:
                living_allies = list(filter(lambda x: x.hp > 0, allies))
                living_enemies = list(filter(lambda x: x.hp > 0, enemies))
                living_heroes = list(filter(lambda x: x.hp > 0, heroes))
                if i in living_allies:
                    if len(living_enemies) != 0:
                        g = self.auto_select(living_enemies)
                        i.turn(roundnum,g)
                elif i.name == 'Gandalf' and i.hp > 0:
                    if len(living_enemies) != 0:
                        g = self.auto_select(living_enemies)
                        self.player_turn(i)
                elif i in living_enemies:
                    if len(living_heroes) != 0:
                        g = self.auto_select(living_heroes)
                        i.turn(roundnum,g)
                        living_allies = list(filter(lambda x: x.hp > 0, allies))
                        if wizard.hp <= 0 or len(living_heroes) == 0 :
                            break
            living_enemies = list(filter(lambda x: x.hp > 0, enemies))
            living_allies = list(filter(lambda x: x.hp > 0, allies))
            living_heroes = list(filter(lambda x: x.hp > 0, heroes))
            print('========================================================')
            print('End of round',str(roundnum)+'.')
            roundnum += 1
        print('========================================================')
        if len(living_enemies) == 0:
            print('Battle over! The good guys won!')
        elif wizard.hp <= 0:
            print('Battle over! Player died!')
        elif len(living_allies) == 0:
            print('Battle over! All your allies are dead!')
        print('========================================================')
        
    def player_turn(self,player):
        print('========================================================')
        print('Player:',player.name,'HP:',str(player.hp)+'/'+str(player.maxHP), 'Mana:'+str(player.mana)+'/100')
        print()
        print('Allies:')
        living_allies = list(filter(lambda x: x.hp > 0, allies))
        living_heroes = list(filter(lambda x: x.hp > 0, heroes))
        for i in living_allies:
            print('',i.name,'HP:'+str(i.hp)+'/'+str(i.maxHP))
        print()
        print('Enemies:')
        living_enemies = list(filter(lambda x: x.hp > 0, enemies))
        for i in living_enemies:
                print('',i.name,'HP:'+str(i.hp)+'/'+str(i.maxHP))
        print('========================================================')
        print('Actions. F: Attack      R: Recharge Mana')
        print('Spells. \n 1: Heal (Costs 20 mana) \n 2: Firebolt \n 3: Mass Heal (Costs 30 mana) \n \
4: Fire Storm (Costs 50 mana)')
        print('To Quit game type: Quit')
        print('========================================================')
        input1 = 'p'
        options = ['F','f','R','r','1','2','3','4','Quit','quit']
        while input1 not in options: 
            input1 = str(input('Enter action: '))
        
        
        if input1 == 'F' or input1 == 'f':
            print('Select target:')
            living_enemies = list(filter(lambda x: x.hp > 0, enemies))
            living_heroes = list(filter(lambda x: x.hp > 0, heroes))
            num = 1
            mylist = []
            for i in living_enemies:
                print(str(num)+':',i.name,'HP:'+str(i.hp)+'/'+str(i.maxHP))
                mylist.append(i)
                num += 1
            input2 = int(input('Enter choice: '))
            enemy = mylist[input2-1]
            player.attack(enemy)
            if enemy.hp <= 0:
                print(enemy.name,'died.')
            
        elif input1 == '2':
            print('Select target:')
            living_enemies = list(filter(lambda x: x.hp > 0, enemies))
            num = 1
            mylist = []
            for i in living_enemies:
                print(str(num)+':',i.name,'HP:'+str(i.hp)+'/'+str(i.maxHP))
                mylist.append(i)
                num += 1
            input2 = int(input('Enter choice: '))
            enemy = mylist[input2-1]
            player.firebolt(enemy)
            if enemy.hp <=0:
                print(enemy.name,'died.')
                
        elif input1 == '1':
            print('Select target:')
            living_heroes = list(filter(lambda x: x.hp > 0, heroes))
            num = 1
            mylist = []
            for i in living_heroes:
                print(str(num)+':',i.name,'HP:'+str(i.hp)+'/'+str(i.maxHP))
                mylist.append(i)
                num += 1
            input2 = int(input('Enter choice: '))
            hero = mylist[input2-1]
            player.heal(hero)
            
        elif input1 == 'R' or input1 == 'r':
            player.recharge()
        elif input1 == '3':
            player.mass_heal(living_heroes)
        elif input1 == '4':
            player.fire_storm(living_enemies)
            
        elif input1 == 'Quit' or input1 == 'quit':
            print('You have quit the game.')
            sys.exit(0)
            
        #elif input1 == 'Quit':                 # Use this Quit command instead of sys.exit(0) if not running in Jupyter
            #print('You have quit the game.')
            #quit()
battle = Battle()
battle.start()
# Out:
# THE BATTLE BEGINS
# ========================================================
# Round 1.
# ========================================================
# Legolas attacks Bolg.
# Attack hits for 10 damage!
# Great Goblin attacks Boromir.
# Attack missed.
# Snaga attacks Legolas.
# Attack missed.
# ========================================================
# Player: Gandalf HP: 40/40 Mana:100/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:50/50
#  Legolas HP:30/30
#
# Enemies:
#  Great Goblin HP:50/50
#  Azog HP:100/100
#  Bolg HP:40/50
#  Shagrat HP:50/50
#  Snaga HP:15/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Mana is already full.
# Aragorn attacks Azog.
# Attack hits for 8 damage!
# Aragorn takes a defensive stance.
# Boromir attacks Azog.
# Attack hits for 9 damage!
# Boromir takes a defensive stance.
# Azog attacks Gandalf.
# Attack missed.
# Azog takes a defensive stance.
# Bolg attacks Legolas.
# Attack missed.
# Shagrat attacks Gandalf.
# Attack missed.
# ========================================================
# End of round 1.
# ========================================================
# Round 2.
# ========================================================
# Legolas's attack increased.
# Legolas's defense decreased.
# Legolas sneak attacks Azog.
# Sneak attack hits for 14 damage.
# Great Goblin's attack increased.
# Great Goblin's defense decreased.
# Great Goblin sneak attacks Boromir.
# Sneak attack hits for 12 damage.
# Snaga attacks Boromir.
# Attack missed.
# ========================================================
# Player: Gandalf HP: 40/40 Mana:100/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:38/50
#  Legolas HP:30/30
#
# Enemies:
#  Great Goblin HP:50/50
#  Azog HP:69/100
#  Bolg HP:40/50
#  Shagrat HP:50/50
#  Snaga HP:15/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 1
# Select target:
# 1: Aragorn HP:50/50
# 2: Boromir HP:38/50
# 3: Legolas HP:30/30
# 4: Gandalf HP:40/40
# Enter choice: 2
# Gandalf heals Boromir for 8 HP.
# Aragorn attacks Bolg.
# Attack missed.
# Boromir attacks Azog.
# Attack hits for 1 damage!
# Azog attacks Legolas.
# Attack missed.
# Bolg attacks Legolas.
# Attack hits for 11 damage!
# Shagrat attacks Legolas.
# Attack missed.
# ========================================================
# End of round 2.
# ========================================================
# Round 3.
# ========================================================
# Legolas sneak attacks Bolg.
# Sneak attack hits for 16 damage.
# Great Goblin sneak attacks Legolas.
# Sneak attack hits for 14 damage.
# Snaga attacks Boromir.
# Attack hits for 7 damage!
# ========================================================
# Player: Gandalf HP: 40/40 Mana:80/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:39/50
#  Legolas HP:5/30
#
# Enemies:
#  Great Goblin HP:50/50
#  Azog HP:68/100
#  Bolg HP:24/50
#  Shagrat HP:50/50
#  Snaga HP:15/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 1
# Select target:
# 1: Aragorn HP:50/50
# 2: Boromir HP:39/50
# 3: Legolas HP:5/30
# 4: Gandalf HP:40/40
# Enter choice: 3
# Gandalf heals Legolas for 6 HP.
# Aragorn attacks Azog.
# Attack hits for 2 damage!
# Boromir attacks Great Goblin.
# Attack missed.
# Azog's stance returns to normal.
# Azog attacks Gandalf.
# Attack hits for 11 damage!
# Bolg attacks Boromir.
# Attack missed.
# Shagrat attacks Aragorn.
# Attack missed.
# ========================================================
# End of round 3.
# ========================================================
# Round 4.
# ========================================================
# Legolas sneak attacks Great Goblin.
# Sneak attack hits for 13 damage.
# Great Goblin sneak attacks Aragorn.
# Sneak attack hits for 8 damage.
# Snaga attacks Boromir.
# Attack missed.
# ========================================================
# Player: Gandalf HP: 29/40 Mana:60/100
#
# Allies:
#  Aragorn HP:42/50
#  Boromir HP:39/50
#  Legolas HP:11/30
#
# Enemies:
#  Great Goblin HP:37/50
#  Azog HP:66/100
#  Bolg HP:24/50
#  Shagrat HP:50/50
#  Snaga HP:15/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 3
# Mana: -30
# Gandalf heals Aragorn for 8 HP.
# Gandalf heals Boromir for 7 HP.
# Gandalf heals Legolas for 7 HP.
# Gandalf heals Gandalf for 10 HP.
# Aragorn's stance returns to normal.
# Aragorn attacks Snaga.
# Attack missed.
# Boromir's stance returns to normal.
# Boromir attacks Bolg.
# Attack missed.
# Azog is in rage.
# Azog attacks Gandalf.
# Attack hits for 18 damage!
# Bolg is in rage.
# Bolg attacks Aragorn.
# Attack missed.
# Shagrat is in rage.
# Shagrat attacks Aragorn.
# Attack missed.
# ========================================================
# End of round 4.
# ========================================================
# Round 5.
# ========================================================
# Legolas's attack decreased.
# Legolas's defense increased.
# Legolas attacks Bolg.
# Attack hits for 11 damage!
# Great Goblin's attack decreased.
# Great Goblin's defense increased.
# Great Goblin attacks Boromir.
# Attack hits for 6 damage!
# Snaga attacks Gandalf.
# Attack missed.
# ========================================================
# Player: Gandalf HP: 21/40 Mana:30/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:40/50
#  Legolas HP:18/30
#
# Enemies:
#  Great Goblin HP:37/50
#  Azog HP:66/100
#  Bolg HP:13/50
#  Shagrat HP:50/50
#  Snaga HP:15/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 3
# Mana: -30
# Aragorn already has full HP.
# Gandalf heals Boromir for 7 HP.
# Gandalf heals Legolas for 6 HP.
# Gandalf heals Gandalf for 13 HP.
# Aragorn attacks Shagrat.
# Attack hits for 7 damage!
# Aragorn takes a defensive stance.
# Boromir attacks Snaga.
# Attack hits for 6 damage!
# Boromir takes a defensive stance.
# Azog cooled down.
# Azog attacks Boromir.
# Attack missed.
# Azog takes a defensive stance.
# Bolg cooled down.
# Bolg attacks Aragorn.
# Attack missed.
# Shagrat cooled down.
# Shagrat attacks Aragorn.
# Attack missed.
# ========================================================
# End of round 5.
# ========================================================
# Round 6.
# ========================================================
# Legolas's attack increased.
# Legolas's defense decreased.
# Legolas sneak attacks Bolg.
# Sneak attack hits for 12 damage.
# Great Goblin's attack increased.
# Great Goblin's defense decreased.
# Great Goblin sneak attacks Gandalf.
# Sneak attack hits for 11 damage.
# Snaga attacks Legolas.
# Attack hits for 7 damage!
# ========================================================
# Player: Gandalf HP: 23/40 Mana:0/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:47/50
#  Legolas HP:17/30
#
# Enemies:
#  Great Goblin HP:37/50
#  Azog HP:66/100
#  Bolg HP:1/50
#  Shagrat HP:43/50
#  Snaga HP:9/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Gandalf channels magical energy...
# Mana: +30
# Aragorn attacks Great Goblin.
# Attack hits for 3 damage!
# Boromir attacks Great Goblin.
# Attack hits for 4 damage!
# Azog attacks Legolas.
# Attack missed.
# Bolg attacks Aragorn.
# Attack missed.
# Shagrat attacks Gandalf.
# Attack missed.
# ========================================================
# End of round 6.
# ========================================================
# Round 7.
# ========================================================
# Legolas sneak attacks Great Goblin.
# Sneak attack hits for 14 damage.
# Great Goblin sneak attacks Legolas.
# Sneak attack hits for 10 damage.
# Snaga attacks Gandalf.
# Attack hits for 8 damage!
# ========================================================
# Player: Gandalf HP: 15/40 Mana:30/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:47/50
#  Legolas HP:7/30
#
# Enemies:
#  Great Goblin HP:16/50
#  Azog HP:66/100
#  Bolg HP:1/50
#  Shagrat HP:43/50
#  Snaga HP:9/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 3
# Mana: -30
# Aragorn already has full HP.
# Gandalf heals Boromir for 3 HP.
# Gandalf heals Legolas for 9 HP.
# Gandalf heals Gandalf for 9 HP.
# Aragorn attacks Bolg.
# Attack hits for 4 damage!
# Bolg died.
# Boromir attacks Shagrat.
# Attack missed.
# Azog's stance returns to normal.
# Azog attacks Boromir.
# Attack hits for 14 damage!
# Shagrat attacks Aragorn.
# Attack missed.
# ========================================================
# End of round 7.
# ========================================================
# Round 8.
# ========================================================
# Legolas sneak attacks Great Goblin.
# Sneak attack hits for 16 damage.
# Great Goblin died.
# Snaga attacks Boromir.
# Attack hits for 7 damage!
# ========================================================
# Player: Gandalf HP: 24/40 Mana:0/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:29/50
#  Legolas HP:16/30
#
# Enemies:
#  Azog HP:66/100
#  Shagrat HP:43/50
#  Snaga HP:9/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Gandalf channels magical energy...
# Mana: +30
# Aragorn's stance returns to normal.
# Aragorn attacks Snaga.
# Attack missed.
# Boromir's stance returns to normal.
# Boromir attacks Snaga.
# Attack missed.
# Azog is in rage.
# Azog attacks Gandalf.
# Attack hits for 18 damage!
# Shagrat is in rage.
# Shagrat attacks Boromir.
# Attack hits for 18 damage!
# ========================================================
# End of round 8.
# ========================================================
# Round 9.
# ========================================================
# Legolas's attack decreased.
# Legolas's defense increased.
# Legolas attacks Azog.
# Attack missed.
# Snaga attacks Boromir.
# Attack missed.
# ========================================================
# Player: Gandalf HP: 6/40 Mana:30/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:11/50
#  Legolas HP:16/30
#
# Enemies:
#  Azog HP:66/100
#  Shagrat HP:43/50
#  Snaga HP:9/15
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 1
# Select target:
# 1: Aragorn HP:50/50
# 2: Boromir HP:11/50
# 3: Legolas HP:16/30
# 4: Gandalf HP:6/40
# Enter choice: 4
# Gandalf heals Gandalf for 6 HP.
# Aragorn attacks Snaga.
# Attack missed.
# Aragorn takes a defensive stance.
# Boromir attacks Shagrat.
# Attack hits for 8 damage!
# Boromir takes a defensive stance.
# Azog cooled down.
# Azog attacks Legolas.
# Attack missed.
# Azog takes a defensive stance.
# Shagrat cooled down.
# Shagrat attacks Legolas.
# Attack missed.
# ========================================================
# End of round 9.
# ========================================================
# Round 10.
# ========================================================
# Legolas's attack increased.
# Legolas's defense decreased.
# Legolas sneak attacks Snaga.
# Sneak attack hits for 18 damage.
# Snaga died.
# ========================================================
# Player: Gandalf HP: 12/40 Mana:10/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:11/50
#  Legolas HP:16/30
#
# Enemies:
#  Azog HP:66/100
#  Shagrat HP:35/50
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Gandalf channels magical energy...
# Mana: +30
# Aragorn attacks Azog.
# Attack missed.
# Boromir attacks Azog.
# Attack missed.
# Azog attacks Aragorn.
# Attack missed.
# Shagrat attacks Legolas.
# Attack hits for 11 damage!
# ========================================================
# End of round 10.
# ========================================================
# Round 11.
# ========================================================
# Legolas sneak attacks Azog.
# Sneak attack hits for 11 damage.
# ========================================================
# Player: Gandalf HP: 12/40 Mana:40/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:11/50
#  Legolas HP:5/30
#
# Enemies:
#  Azog HP:55/100
#  Shagrat HP:35/50
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 3
# Mana: -30
# Aragorn already has full HP.
# Gandalf heals Boromir for 10 HP.
# Gandalf heals Legolas for 6 HP.
# Gandalf heals Gandalf for 5 HP.
# Aragorn attacks Azog.
# Attack hits for 3 damage!
# Boromir attacks Shagrat.
# Attack hits for 4 damage!
# Azog's stance returns to normal.
# Azog attacks Boromir.
# Attack missed.
# Shagrat attacks Boromir.
# Attack missed.
# ========================================================
# End of round 11.
# ========================================================
# Round 12.
# ========================================================
# Legolas sneak attacks Shagrat.
# Sneak attack hits for 13 damage.
# ========================================================
# Player: Gandalf HP: 17/40 Mana:10/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:21/50
#  Legolas HP:11/30
#
# Enemies:
#  Azog HP:52/100
#  Shagrat HP:18/50
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Gandalf channels magical energy...
# Mana: +30
# Aragorn's stance returns to normal.
# Aragorn attacks Azog.
# Attack hits for 6 damage!
# Boromir's stance returns to normal.
# Boromir attacks Azog.
# Attack hits for 7 damage!
# Azog is in rage.
# Azog attacks Aragorn.
# Attack missed.
# Shagrat is in rage.
# Shagrat attacks Legolas.
# Attack missed.
# ========================================================
# End of round 12.
# ========================================================
# Round 13.
# ========================================================
# Legolas's attack decreased.
# Legolas's defense increased.
# Legolas attacks Shagrat.
# Attack hits for 10 damage!
# ========================================================
# Player: Gandalf HP: 17/40 Mana:40/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:21/50
#  Legolas HP:11/30
#
# Enemies:
#  Azog HP:39/100
#  Shagrat HP:8/50
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 3
# Mana: -30
# Aragorn already has full HP.
# Gandalf heals Boromir for 11 HP.
# Gandalf heals Legolas for 5 HP.
# Gandalf heals Gandalf for 11 HP.
# Aragorn attacks Azog.
# Attack hits for 8 damage!
# Aragorn takes a defensive stance.
# Boromir attacks Azog.
# Attack hits for 8 damage!
# Boromir takes a defensive stance.
# Azog cooled down.
# Azog attacks Gandalf.
# Attack hits for 14 damage!
# Azog takes a defensive stance.
# Shagrat cooled down.
# Shagrat attacks Legolas.
# Attack missed.
# ========================================================
# End of round 13.
# ========================================================
# Round 14.
# ========================================================
# Legolas's attack increased.
# Legolas's defense decreased.
# Legolas sneak attacks Shagrat.
# Sneak attack hits for 17 damage.
# Shagrat died.
# ========================================================
# Player: Gandalf HP: 14/40 Mana:10/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:32/50
#  Legolas HP:16/30
#
# Enemies:
#  Azog HP:23/100
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: r
# Gandalf channels magical energy...
# Mana: +30
# Aragorn attacks Azog.
# Attack missed.
# Boromir attacks Azog.
# Attack hits for 4 damage!
# Azog attacks Boromir.
# Attack missed.
# ========================================================
# End of round 14.
# ========================================================
# Round 15.
# ========================================================
# Legolas sneak attacks Azog.
# Sneak attack hits for 11 damage.
# ========================================================
# Player: Gandalf HP: 14/40 Mana:40/100
#
# Allies:
#  Aragorn HP:50/50
#  Boromir HP:32/50
#  Legolas HP:16/30
#
# Enemies:
#  Azog HP:8/100
# ========================================================
# Actions. F: Attack      R: Recharge Mana
# Spells.
#  1: Heal (Costs 20 mana)
#  2: Firebolt
#  3: Mass Heal (Costs 30 mana)
#  4: Fire Storm (Costs 50 mana)
# To Quit game type: Quit
# ========================================================
# Enter action: 1
# Select target:
# 1: Aragorn HP:50/50
# 2: Boromir HP:32/50
# 3: Legolas HP:16/30
# 4: Gandalf HP:14/40
# Enter choice: 4
# Gandalf heals Gandalf for 7 HP.
# Aragorn attacks Azog.
# Attack missed.
# Boromir attacks Azog.
# Attack missed.
# Azog's stance returns to normal.
# Azog attacks Boromir.
# Attack missed.
# ========================================================
# End of round 15.
# ========================================================
# Round 16.
# ========================================================
# Legolas sneak attacks Azog.
# Sneak attack hits for 18 damage.
# Azog died.
# ========================================================
# End of round 16.
# ========================================================
# Battle over! The good guys won!
# ========================================================
